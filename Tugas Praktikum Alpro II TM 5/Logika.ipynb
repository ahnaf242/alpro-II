# %%
from Database import mahasiswa

def cari_mahasiswa(NIM):
    for row in mahasiswa():
        if row['NIM'] == NIM:
            return row
# Out:
# {'NIM': '164241025', 'Nama': 'Ahnaf Umar', 'Asal Kota': 'Surabaya'}
